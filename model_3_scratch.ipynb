# %% [markdown]
# # Model 3 Scratch

# %% [markdown]
# Implement variational inference for the Gamma-Poisson model with latent categorical factors following a hidden Markov model.

# %%
from __future__ import division
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %% [markdown]
# ## Let's make fake data

# %%
np.random.seed(12345)

# %%
U = 100  # units
T = 5000  # time points/frames
M = 2  # number of latent states
Kdata = 5  # categories
dt = 1 / 30  # frames per second

# %%
# 0 -> 1 transition should be small
v0_a = 1
v0_b = 200
xx = np.linspace(0, 1, 1000)
plt.plot(xx, stats.beta.pdf(xx, v0_a, v0_b));

# 1 -> 1 transition should be large
v1_a = 100
v1_b = 1
xx = np.linspace(0, 1, 1000)
plt.plot(xx, stats.beta.pdf(xx, v1_a, v1_b));

# %%
# make vector of transition probabilities
# each row is a category, each column the transition
# probability from that state to state 1
# (this is easy to do without matrices since we have
# only two states)
v0 = stats.beta.rvs(v0_a, v0_b, size=Kdata)
v1 = stats.beta.rvs(v1_a, v1_b, size=Kdata)
trans_probs = np.vstack([v0, v1]).T

# %%
# pick initial states for each category
z0_probs = stats.beta.rvs(50, 50, size=Kdata)
z0 = stats.bernoulli.rvs(z0_probs)

# %%
# make the chain by evolving each category through time
chain = np.empty((Kdata, T), dtype='int')

# initialize
chain[:, 0] = z0

for t in xrange(1, T):
    p_trans_to_1 = trans_probs[range(Kdata), chain[:, t - 1]]
    chain[:, t] = stats.bernoulli.rvs(p_trans_to_1)
    
# include a baseline regressor that is always turned on
chain[0, :] = 1

# %%
# plot the categories through time
Trng = (0, 500)
plt.matshow(chain[:, slice(*Trng)], aspect='auto', cmap=cm.gray);

# %%
# set up firing rates for each category, unit
aa = 3, 1
bb = 2, 1
lam = stats.gamma.rvs(a=aa[1], scale=bb[1], size=(Kdata, U))
lam[0, :] = stats.gamma.rvs(a=aa[0], scale=bb[0], size=U)  # baselines

xx = np.linspace(0, 40, 1000)
plt.plot(xx, stats.gamma.pdf(xx, a=aa[0], scale=bb[0]));
plt.plot(xx, stats.gamma.pdf(xx, a=aa[1], scale=bb[1]));
plt.legend(['Baseline', 'Effects']);
plt.ylim([0, 0.5]);

# %%
# calculate rate for each time
fr = np.exp(chain.T.dot(np.log(lam))) * dt
fr = fr + 1e-5  # in case we get exactly 0
plt.matshow(chain, aspect='auto', cmap=cm.gray);
plt.matshow(fr.T, aspect='auto', cmap=cm.gray);

# draw from Poisson
N = stats.poisson.rvs(fr)
plt.matshow(N.T, aspect='auto', cmap=cm.gray);

# %% [markdown]
# ## Priors

# %%
# choose a different number of categories to fit in the model
K = 5

# %% [markdown]
# ### $\lambda$

# %%
# multipliers shouldn't be much bigger than ~4
cmat = 2 * np.ones((K, U))
dmat = 2 * np.ones((K, U)) / dt

# baselines can be a lot bigger
cmat[0, :] = 3
dmat[0, :] = 1/6 / dt

# %%
xx = np.linspace(0, 100)
plt.subplot(1, 2, 1)
plt.plot(xx, stats.gamma.pdf(xx, cmat[0,0], scale=1 / (dmat[0, 0] * dt)));
plt.title('Baseline');

xx = np.linspace(0, 5)
plt.subplot(1, 2, 2)
plt.plot(xx, stats.gamma.pdf(xx, cmat[1,0], scale=1 / (dmat[1, 0] * dt )));
plt.title('Multiplicative Effects');

# %% [markdown]
# ### $A$

# %% [markdown]
# Here, we choose weakly informative priors based on the assumption that $A_{0 \rightarrow 1}$ is small and $A_{1 \rightarrow 1}$ is large.

# %%
nu1_mat = np.r_[np.ones((1, K)), 10 * np.ones((1, K))]
nu2_mat = np.r_[10 * np.ones((1, K)), np.ones((1, K))]

# %% [markdown]
# ### $\pi_0$

# %%
rho1_mat = np.ones((K,))
rho2_mat = np.ones((K,))

# %%
xx = np.linspace(0, 1, 1000)
plt.plot(xx, stats.beta.pdf(xx, 1, 10));
plt.plot(xx, stats.beta.pdf(xx, 10, 1));

# %% [markdown]
# ## Initial Values

# %% [markdown]
# ### $q(\lambda|z)$

# %%
alpha_mat = np.sum(N, axis = 0) + 1 + cmat

# start by assuming beta very large
beta_mat = dmat + 100000

# %% [markdown]
# ### $q(A)$

# %%
# for an initial guess for A's posterior params, just take the the prior
gamma1_mat = nu1_mat
gamma2_mat = nu2_mat

# %% [markdown]
# ### $q(\pi_0)$

# %%
# again, just take the prior
delta1_mat = rho1_mat
delta2_mat = rho2_mat

# %% [markdown]
# ### $\xi$, $\Xi$

# %%
#xi_mat = np.round(0.1 * np.random.rand(T, K))
xi_mat = np.zeros((T, K))
xi_mat[:, 0] = 1  # baseline

Xi = np.random.rand(T - 1, M, M, K)

# and two-slice marginal for baseline
Xi[..., 0] = 0
Xi[:, 1, 1, 0] = 1

# %% [markdown]
# ## Forward-Backward

# %% [markdown]
# Given observations $y$, $\pi_0$ (initial state distribution), and $A_{i \rightarrow j}$ (transition matrix), return the posterior probabilities of the latent states $z_{1:T}$ and the partition function $Z = p(\mathcal{D})$. Notational conventions for intermediate quantities in the algorithm follows Murphy (Machine Learning: A probabilistic approach).

# %%
def fb_infer(y, lam, A, pi0):
    # implement the forward-backward inference algorithm
    # y is a times x units matrix of observations (counts)
    # lam is a times x units x states array of Poisson rates
    # A is a matrix of transition probabilities that acts to the right:
    # new_state = A * old_state, so that columns of A sum to 1
    T = y.shape[0]
    M = A.shape[0]

    # initialize empty variables
    zmat = np.empty((T, K))  # latent states
    alpha = np.empty((T, M))  # p(z_t|y_{1:T})
    beta = np.empty((T, M))  # p(y_{t+1:T}|z_t) (unnormalized)
    psi = np.empty((T, M))  # p(y_t|z_t) (observation model)
    logpsi = np.empty((T, M))
    gamma = np.empty((T, M))  # p(z_t|y_{1:T}) (posterior)
    logZ = np.empty(T)  # log partition function
    
    # sanitize inputs
    lam_min = 1e-100
    ll = lam.copy()
    ll[ll == 0] = lam_min
    
    # Poisson observation model
    # product over all units for each time
    # z = 0
    logpsi[:, 0] = np.sum(stats.poisson.logpmf(y, ll[..., 0]), axis=1)

    # z = 1
    logpsi[:, 1] = np.sum(stats.poisson.logpmf(y, ll[..., 1]), axis=1)
    
    # take care of underflow
    logpsi = logpsi - np.amax(logpsi, 1, keepdims=True)
    psi = np.exp(logpsi)
    
    # initialize
    alpha[0, :] = pi0
    beta[-1, :] = 1
    logZ[0] = 0
    
    # forwards
    for t in xrange(1, T):
        a = psi[t, :] * (A.dot(alpha[t - 1, :]))
        logZ[t] = np.sum(a)
        alpha[t, :] = a / np.sum(a)
        
    # backwards
    for t in xrange(T - 1, 0, -1):
        b = A.T.dot(beta[t, :] * psi[t, :])
        beta[t - 1, :] = b / np.sum(b)
        
    # posterior
    gamma = alpha * beta
    gamma = gamma / np.sum(gamma, 1, keepdims=True)
    
    # two-slice marginal matrix: xi = p(z_{t+1}, z_t|y_{1:T})
    beta_shift = np.expand_dims(np.roll(beta * psi, shift=-1, axis=0), 2)

    # take outer product; make sure t axis on alpha < T
    # and t+1 axis on bp > 0
    xi = beta_shift[1:] * alpha[:-1, np.newaxis, :]

    #normalize
    xi = xi / np.sum(xi, axis=(1, 2), keepdims=True)
    if np.any(np.isnan(gamma)):
        fail
    return gamma, np.sum(logZ), xi

# %% [markdown]
# Let's test this on some fake data:

# %%
idx = 1
num_units = 10

# series of states: ground truth
ztest = chain[idx, :]

# rates for each unit
mu0 = np.random.rand(num_units)
mu = 5 * np.random.rand(num_units)
mu_stack = np.dstack([mu0, mu0 + mu])

# series of observations: ground truth
rates = mu0 + np.outer(ztest, mu)
Ntest = stats.poisson.rvs(rates)

# transition matrix
to_1 = np.expand_dims(trans_probs[idx, :], 0)
A = np.r_[1 - to_1, to_1]

# initial belief about states
pi_0 = np.array([0.5, 0.5])

# %%
posterior, logZ, Xi_test = fb_infer(Ntest, mu_stack, A, pi_0)

# %%
# plot results
Trng = (0, 5000)
plt.matshow(ztest[slice(*Trng)].reshape((-1, 1)).T, aspect='auto', cmap=cm.gray);
plt.matshow(posterior[slice(*Trng), [1]].T, aspect='auto', cmap=cm.gray, vmin=0, vmax=1);

# %% [markdown]
# ## Inference

# %%
from scipy.special import digamma

# %%
def make_exclusive_product(zbar, w):
    """
    returns prod_{j \neq k} (1 - zbar_tj + zbar_tj * w_ju)
    """
    zb = zbar[..., np.newaxis]
    vv = 1 - zb + zb * w
    dd = np.prod(vv, 1, keepdims=True)
    return dd / vv

# %%
def update(N, pars, priors):
    (alpha_mat, beta_mat, gamma1_mat, gamma2_mat,
     delta1_mat, delta2_mat, xi_mat, Xi) = pars
    (cmat, dmat, nu1_mat, nu2_mat, rho1_mat,
     rho2_mat) = priors

    M = nu1_mat.shape[0]
    T, U = N.shape
    K = alpha_mat.shape[0]
    
    ######### get parameters for forwards-backwards
    # A
    log_A_fb = np.empty((M, M, K))
    log_A_fb[1, :] = digamma(gamma1_mat) - digamma(gamma1_mat + gamma2_mat)
    A_fb = np.exp(log_A_fb)
    A_fb[0, :] = 1 - A_fb[1, :]
    
    # pi0
    pi0_fb = np.empty((M, K))
    pi0_fb[1, :] = delta1_mat / (delta1_mat + delta2_mat)
    pi0_fb[0, :] = 1 - pi0_fb[1, :]
    
    ########## next, run forward-backward to get xi_mat and Xi
    
    logZ = np.empty((K,))
    for k in xrange(K):
        # update mean field parameters
        mu_mat = np.exp(digamma(alpha_mat) - np.log(beta_mat))
        eta_mat = make_exclusive_product(xi_mat, mu_mat)
        lam = np.empty((T, K, U, M))
        lam[..., 0] = eta_mat
        lam[..., 1] = eta_mat * mu_mat
        
        ######### update lambda parameters
        alpha_mat = np.sum(N, axis = 0) + 1 + cmat
        beta_mat = np.sum(make_exclusive_product(xi_mat, alpha_mat / beta_mat), 0) + dmat
        
        if k > 0:
            post, logZ[k], Xi[..., k] = fb_infer(N, lam[:, k], A_fb[:, :, k], pi0_fb[:, k])
            xi_mat[:, k] = post[:, 1]
        else:
            # first off, baseline (k = 0) is always on
            xi_mat[:, 0] = 1
            Xi0 = np.zeros((M, M))
            Xi0[1, 1] = 1
            Xi[:, :, :, 0] = np.tile(Xi0, (T - 1, 1, 1))
            logZ[0] = 1
        
    # A params
    Xi_red = np.sum(Xi, 0)
    gamma1_mat = nu1_mat + Xi_red[1]
    gamma2_mat = nu2_mat + Xi_red[0]
    
    # pi0 params
    delta1_mat = rho1_mat + xi_mat[0]
    delta2_mat = rho2_mat + 1 - xi_mat[0]
    
    pars = (alpha_mat, beta_mat, gamma1_mat, gamma2_mat,
     delta1_mat, delta2_mat, xi_mat, Xi)
    
    return pars

# %%
# tuple of initial values
pars0 = (alpha_mat, beta_mat, gamma1_mat, gamma2_mat,
     delta1_mat, delta2_mat, xi_mat, Xi)
priors = (cmat, dmat, nu1_mat, nu2_mat, rho1_mat, rho2_mat)

# %%
pars = update(N, pars0, priors)

# %%
parlist = [pars0]
for ind in xrange(10):
    pars = update(N, pars, priors)
    parlist.append(pars)
# Out:
# -c:15: RuntimeWarning: overflow encountered in exp

# %%
Trng = (500, 1000)
plt.matshow(chain[:, slice(*Trng)], aspect='auto', cmap=cm.gray, vmin=0, vmax=1);
plt.matshow(pars[6].T[:, slice(*Trng)], aspect='auto', cmap=cm.gray, vmin=0, vmax=1);

# %%
plt.matshow(chain, aspect='auto', cmap=cm.gray, vmin=0, vmax=1);
plt.matshow(pars[6].T, aspect='auto', cmap=cm.gray, vmin=0, vmax=1);

# %%
#Npred = pars[9].dot(pars[6])
plt.matshow(chain, aspect='auto', cmap=cm.gray);
#plt.matshow(pars[9].T, aspect='auto', cmap=cm.gray, vmin=0, vmax=1);
plt.matshow(fr.T, aspect='auto', cmap=cm.gray);
plt.matshow(N.T, aspect='auto', cmap=cm.gray, vmin=0, vmax=np.max(N));
#plt.matshow(Npred.T, aspect='auto', cmap=cm.gray, vmin=0, vmax=np.max(N));
